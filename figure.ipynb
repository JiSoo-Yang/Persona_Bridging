# %% [markdown]
# ```mermaid
# flowchart TD
#     A[🚀 Start] --> B[🎲 Generate Persona<br/>4 attributes]
#
#     B --> C[🤖 Create Models]
#     C --> D[🕵️ Tool Agent<br/>GPT-4]
#     C --> E[🎯 Target LLM<br/>HF Model]
#
#     D --> F[💬 Interview Loop]
#     E --> F
#
#     F --> G[Ask Question 1]
#     G --> H[Get Answer 1]
#     H --> I[Ask Question 2]
#     I --> J[Get Answer 2]
#     J --> K[... Ask Question N]
#     K --> L[Get Answer N]
#
#     L --> O[🧠 Step 1: Extract Bridging Relations<br/>Find implicit connections]
#     O --> Q[📊 Step 2: Create Importance Graph<br/>JSON + PNG]
#     Q --> T[🎯 Predict 4 Attributes<br/>Social Role, Personality, Background, Interests]
#
#
#     style A fill:#e1f5e1
#     style B fill:#fff4e1
#     style D fill:#e1f0ff
#     style E fill:#ffe1f0
#     style F fill:#f0e1ff
#     style O fill:#e1f5ff
#     style Q fill:#e1f5ff
#     style T fill:#e1f5e1
# ```

# %% [markdown]
# ```mermaid
# flowchart TD
#     Start([🚀 Start System]) --> Setup[⚙️ Setup]
#
#     Setup --> GT[🔒 Ground Truth\\nHIDDEN from Agent]
#     Setup --> PT[📋 Prediction Template\\nGiven to Agent]
#     Setup --> Inject[🎭 Inject to Target LLM]
#
#     GT -.->|Social Role: Athlete\\nConscientiousness: NO\\nEconomic: Low Income\\nStyle: Logical| Hidden[Hidden]
#
#     PT -->|Social Role: ??\\nConscientiousness: ??\\nEconomic_status: ??\\nCommunication_style: ??| Agent[🕵️ Tool Agent]
#
#     Inject -->|You are Athlete\\nLow conscientiousness\\nLow income\\nLogical style| Target[🎯 Target LLM]
#
#     Agent --> Q1[💬 Question 1:\\n"How do you plan your day?"]
#     Target --> A1[💬 Answer 1:\\n"I go with the flow,\\nno strict schedule"]
#     Q1 --> A1
#
#     A1 --> Analyze1[🔍 Agent Analysis:\\n"go with flow" → Low conscientiousness]
#
#     Analyze1 --> Q2[💬 Question 2:\\n"What equipment do you use?"]
#     Target --> A2[💬 Answer 2:\\n"Public facilities,\\nbasic gear,\\ncan't afford expensive"]
#     Q2 --> A2
#
#     A2 --> Analyze2[🔍 Agent Analysis:\\n"public facilities"\\n"can't afford" → Low income]
#
#     Analyze2 --> Q3[💬 Question 3:\\n"How do you make training decisions?"]
#     Target --> A3[💬 Answer 3:\\n"Analyze data,\\ncompare options,\\nbased on evidence"]
#     Q3 --> A3
#
#     A3 --> Analyze3[🔍 Agent Analysis:\\n"analyze data"\\n"evidence" → Logical style]
#
#     Analyze3 --> Extract[🧠 Extract Bridging Relations]
#
#     Extract --> B1[Bridging 1:\\ntraining → public facilities\\nIN relation → Low resources]
#     Extract --> B2[Bridging 2:\\ndecisions → performance data\\nINSTRUMENT → Logical]
#     Extract --> B3[Bridging 3:\\nplanning → go with flow\\nTHEME → Low organization]
#
#     B1 --> Graph[📊 Create Graph]
#     B2 --> Graph
#     B3 --> Graph
#
#     Graph --> Nodes[Important Nodes:\\n1. training (3 connections)\\n2. data (2 connections)\\n3. facilities (2 connections)]
#
#     Nodes --> Predict[🎯 PREDICT]
#
#     Predict --> P1[Prediction 1:\\nSocial Role = ATHLETE]
#     Predict --> P2[Prediction 2:\\nConscientiousness = NO]
#     Predict --> P3[Prediction 3:\\nEconomic = LOW INCOME]
#     Predict --> P4[Prediction 4:\\nStyle = LOGICAL]
#
#     P1 --> Compare[✅ Compare with Ground Truth]
#     P2 --> Compare
#     P3 --> Compare
#     P4 --> Compare
#
#     Hidden -.->|Reveal for comparison| Compare
#
#     Compare --> Result[🎉 Result:\\nAthlete ✅\\nConscientiousness: NO ✅\\nLow Income ✅\\nLogical ✅\\nAccuracy: 4/4 = 100%]
#
#     Result --> End([✅ Complete])
#
#     style GT fill:#ffcccc
#     style PT fill:#ffffcc
#     style Hidden fill:#ffcccc
#     style Agent fill:#ccddff
#     style Target fill:#ffccff
#     style Analyze1 fill:#ccffcc
#     style Analyze2 fill:#ccffcc
#     style Analyze3 fill:#ccffcc
#     style Extract fill:#e6ccff
#     style Graph fill:#cce6ff
#     style Predict fill:#ffeecc
#     style Compare fill:#ccffcc
#     style Result fill:#ccffcc
# ```
